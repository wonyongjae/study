# %% [markdown]
# # Matplotlib
# 다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 그래프 기본

# %%
x = [1,2,3]
y = [2,4,8]
plt.plot(x,y)

# %%
print(plt.plot(x,y))
# Out:
# [<matplotlib.lines.Line2D object at 0x000001DD523DB820>]

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Title 설정

# %%
plt.plot(x,y)
plt.title('Line Graph')
# Out:
# Text(0.5, 1.0, 'Line Graph')

# %%
plt.plot(x,y)
plt.title('꺽은선 그래프')
# Out:
# Text(0.5, 1.0, '꺽은 선 그래프')
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44733 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51008 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49440 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47000 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54532 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44733 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51008 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49440 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47000 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 54532 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## 한글 폰트 설정

# %%
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
# matplotlib.rcParams['font.family'] = 'AppleGothic'   Mac
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
import matplotlib.font_manager as fm
fm.fontManager.ttflist # 사용 가능한 폰트 확인
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['DejaVu Serif',
#  'DejaVu Sans Mono',
#  'cmsy10',
#  'cmr10',
#  'DejaVu Serif',
#  'STIXSizeFourSym',
#  'cmmi10',
#  'DejaVu Sans',
#  'cmex10',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'STIXGeneral',
#  'STIXSizeTwoSym',
#  'STIXSizeTwoSym',
#  'cmb10',
#  'DejaVu Sans Display',
#  'cmtt10',
#  'STIXNonUnicode',
#  'STIXSizeFourSym',
#  'STIXSizeOneSym',
#  'DejaVu Sans Mono',
#  'cmss10',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'DejaVu Serif Display',
#  'STIXSizeThreeSym',
#  'STIXGeneral',
#  'STIXSizeThreeSym',
#  'DejaVu Sans Mono',
#  'DejaVu Sans',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'STIXSizeFiveSym',
#  'STIXSizeOneSym',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'Stencil',
#  'Rockwell Condensed',
#  'Chiller',
#  'MS Outlook',
#  'Palatino Linotype',
#  'Wingdings 2',
#  'Gabriola',
#  'Lucida Sans Typewriter',
#  'Times New Roman',
#  'Lucida Bright',
#  'Ravie',
#  'Leelawadee UI',
#  'Microsoft Sans Serif',
#  'Rockwell',
#  'Sitka Small',
#  'Pristina',
#  'High Tower Text',
#  'Leelawadee UI',
#  'Agency FB',
#  'Britannic Bold',
#  'Brush Script MT',
#  'Malgun Gothic',
#  'HYHeadLine-Medium',
#  'Calisto MT',
#  'Verdana',
#  'Arial',
#  'Bernard MT Condensed',
#  'Batang',
#  'Franklin Gothic Heavy',
#  'HYSinMyeongJo-Medium',
#  'Yu Gothic',
#  'Century',
#  'Trebuchet MS',
#  'Microsoft New Tai Lue',
#  'MingLiU-ExtB',
#  'Century Schoolbook',
#  'Bodoni MT',
#  'Calisto MT',
#  'Candara',
#  'Imprint MT Shadow',
#  'Ink Free',
#  'Microsoft PhagsPa',
#  'Rage Italic',
#  'Cooper Black',
#  'Yu Gothic',
#  'Marlett',
#  'Microsoft Himalaya',
#  'Lucida Sans',
#  'Sitka Small',
#  'Franklin Gothic Demi',
#  'Freestyle Script',
#  'Gill Sans MT Ext Condensed Bold',
#  'Wide Latin',
#  'Cambria',
#  'Tw Cen MT',
#  'Georgia',
#  'Segoe Print',
#  'Bodoni MT',
#  'Segoe UI',
#  'Lucida Sans Typewriter',
#  'Bodoni MT',
#  'Cambria',
#  'Franklin Gothic Medium',
#  'Century Schoolbook',
#  'Candara',
#  'Eras Bold ITC',
#  'Lucida Bright',
#  'Microsoft JhengHei',
#  'Lucida Console',
#  'Nirmala UI',
#  'Gill Sans MT',
#  'Bodoni MT',
#  'Gill Sans MT',
#  'Informal Roman',
#  'Arial',
#  'Californian FB',
#  'Arial',
#  'Copperplate Gothic Bold',
#  'Lucida Sans Typewriter',
#  'HCR Batang',
#  'Berlin Sans FB Demi',
#  'Arial',
#  'Lucida Bright',
#  'Tempus Sans ITC',
#  'MS Gothic',
#  'Century Schoolbook',
#  'Lucida Sans Typewriter',
#  'Book Antiqua',
#  'Segoe UI',
#  'Dubai',
#  'Bookman Old Style',
#  'Courier New',
#  'Gill Sans MT Condensed',
#  'Arial',
#  'Courier New',
#  'Georgia',
#  'Bell MT',
#  'Corbel',
#  'Century Gothic',
#  'Bookman Old Style',
#  'Lucida Fax',
#  'Consolas',
#  'NanumGothic',
#  'Verdana',
#  'Candara',
#  'Sitka Small',
#  'Comic Sans MS',
#  'Microsoft Uighur',
#  'Colonna MT',
#  'Book Antiqua',
#  'Gloucester MT Extra Condensed',
#  'Franklin Gothic Demi Cond',
#  'Nirmala UI',
#  'Microsoft JhengHei',
#  'Blackadder ITC',
#  'Berlin Sans FB',
#  'Corbel',
#  'Leelawadee',
#  'Times New Roman',
#  'Palatino Linotype',
#  'Kunstler Script',
#  'Algerian',
#  'Leelawadee UI',
#  'Goudy Stout',
#  'Microsoft New Tai Lue',
#  'Harrington',
#  'Calibri',
#  'MoeumT R',
#  'ZWAdobeF',
#  'HCR Dotum Ext',
#  'Constantia',
#  'Lucida Sans',
#  'Bodoni MT',
#  'HYShortSamul-Medium',
#  'Eras Light ITC',
#  'Segoe UI',
#  'Lucida Fax',
#  'Trebuchet MS',
#  'Broadway',
#  'Cambria',
#  'Franklin Gothic Demi',
#  'Gill Sans Ultra Bold Condensed',
#  'Bauhaus 93',
#  'Lucida Handwriting',
#  'Mongolian Baiti',
#  'Gill Sans MT',
#  'Garamond',
#  'HoloLens MDL2 Assets',
#  'Forte',
#  'HYPMokGak-Bold',
#  'Papyrus',
#  'Segoe UI',
#  'Corbel',
#  'Han Santteut Dotum',
#  'Perpetua',
#  'Segoe UI',
#  'Arial Rounded MT Bold',
#  'Segoe UI',
#  'Century Schoolbook',
#  'Lucida Fax',
#  'Century Gothic',
#  'Arial',
#  'Candara',
#  'Corbel',
#  'NewJumja',
#  'Eras Demi ITC',
#  'Segoe Print',
#  'Dubai',
#  'Perpetua Titling MT',
#  'Cambria',
#  'Elephant',
#  'Microsoft Tai Le',
#  'Showcard Gothic',
#  'Lucida Sans',
#  'HCR Batang ExtB',
#  'Tw Cen MT',
#  'Ami R',
#  'Microsoft YaHei',
#  'Copperplate Gothic Light',
#  'Lucida Sans',
#  'Haettenschweiler',
#  'Edwardian Script ITC',
#  'Ebrima',
#  'Rockwell Condensed',
#  'Viner Hand ITC',
#  'Haan Wing2',
#  'Agency FB',
#  'Tw Cen MT Condensed',
#  'Franklin Gothic Book',
#  'Franklin Gothic Heavy',
#  'HCR Batang ExtB',
#  'HYPost-Light',
#  'Snap ITC',
#  'Onyx',
#  'Microsoft Tai Le',
#  'Georgia',
#  'Sylfaen',
#  'Segoe UI',
#  'Gadugi',
#  'Tw Cen MT',
#  'Segoe Script',
#  'Niagara Solid',
#  'HYPost-Medium',
#  'Magic R',
#  'New Gulim',
#  'Symbol',
#  'Perpetua',
#  'Palace Script MT',
#  'Myanmar Text',
#  'Impact',
#  'Segoe MDL2 Assets',
#  'Microsoft PhagsPa',
#  'Segoe UI',
#  'Curlz MT',
#  'Calibri',
#  'Calibri',
#  'Microsoft YaHei',
#  'Kristen ITC',
#  'Bodoni MT',
#  'Georgia',
#  'Centaur',
#  'Malgun Gothic',
#  'Tw Cen MT Condensed Extra Bold',
#  'Constantia',
#  'Calibri',
#  'Baskerville Old Face',
#  'Perpetua',
#  'Microsoft Yi Baiti',
#  'Gigi',
#  'MT Extra',
#  'Bell MT',
#  'Segoe UI Symbol',
#  'Dubai',
#  'Wingdings 3',
#  'Tw Cen MT',
#  'Goudy Old Style',
#  'HYGungSo-Bold',
#  'Eras Medium ITC',
#  'Consolas',
#  'Niagara Engraved',
#  'Mistral',
#  'Corbel',
#  'Palatino Linotype',
#  'Microsoft YaHei',
#  'Arial',
#  'Bodoni MT',
#  'HYGothic-Medium',
#  'Microsoft Uighur',
#  'Webdings',
#  'Segoe UI Emoji',
#  'OCR A Extended',
#  'Candara',
#  'Elephant',
#  'Bell MT',
#  'HancomEQN',
#  'Palatino Linotype',
#  'French Script MT',
#  'Maiandra GD',
#  'Garamond',
#  'Lucida Sans',
#  'Goudy Old Style',
#  'Magneto',
#  'Constantia',
#  'Yet R',
#  'Candara',
#  'Rockwell',
#  'HCR Dotum',
#  'Comic Sans MS',
#  'Vivaldi',
#  'V3Detect',
#  'Century Gothic',
#  'Segoe UI Historic',
#  'Lucida Bright',
#  'Bodoni MT',
#  'Rockwell Extra Bold',
#  'HYGothic-Extra',
#  'Myanmar Text',
#  'HYMyeongJo-Extra',
#  'Rockwell',
#  'Lucida Bright',
#  'Franklin Gothic Book',
#  'Century Gothic',
#  'Calibri',
#  'HYGraphic-Medium',
#  'Javanese Text',
#  'Gulim',
#  'Poor Richard',
#  'Courier New',
#  'Tw Cen MT Condensed',
#  'HCR Batang Ext',
#  'Times New Roman',
#  'Dubai',
#  'Segoe UI',
#  'Calisto MT',
#  'Monotype Corsiva',
#  'Consolas',
#  'Malgun Gothic',
#  'Courier New',
#  'Trebuchet MS',
#  'Hancom Gothic',
#  'Headline R',
#  'Gill Sans MT',
#  'Juice ITC',
#  'Ebrima',
#  'Comic Sans MS',
#  'Pyunji R',
#  'MS Reference Sans Serif',
#  'Lucida Sans',
#  'Script MT Bold',
#  'Times New Roman',
#  'HyhwpEQ',
#  'Vladimir Script',
#  'MV Boli',
#  'Californian FB',
#  'SimSun-ExtB',
#  'Nirmala UI',
#  'Bookshelf Symbol 7',
#  'Tahoma',
#  'Perpetua',
#  'Gill Sans Ultra Bold',
#  'Playbill',
#  'Lucida Bright',
#  'Bradley Hand ITC',
#  'Hancom Gothic',
#  'Lucida Sans Unicode',
#  'Arial',
#  'Matura MT Script Capitals',
#  'Han Santteut Dotum',
#  'High Tower Text',
#  'Yu Gothic',
#  'Calisto MT',
#  'Parchment',
#  'Felix Titling',
#  'Garamond',
#  'Berlin Sans FB',
#  'Constantia',
#  'Segoe Script',
#  'Lucida Calligraphy',
#  'Yu Gothic',
#  'Segoe UI',
#  'Bahnschrift',
#  'Old English Text MT',
#  'Bodoni MT',
#  'Arial',
#  'Gadugi',
#  'Modern No. 20',
#  'Euro Sign',
#  'Franklin Gothic Medium',
#  'Wingdings',
#  'Bookman Old Style',
#  'MS Reference Specialty',
#  'Leelawadee',
#  'Rockwell',
#  'Consolas',
#  'Book Antiqua',
#  'Sitka Small',
#  'Footlight MT Light',
#  'Verdana',
#  'Lucida Fax',
#  'Segoe UI',
#  'HCR Dotum',
#  'Verdana',
#  'Bookman Old Style',
#  'SimSun',
#  'Perpetua Titling MT',
#  'Calibri',
#  'Goudy Old Style',
#  'Bodoni MT',
#  'Jokerman',
#  'Corbel',
#  'Microsoft JhengHei',
#  'Segoe UI',
#  'Trebuchet MS',
#  'HCR Batang',
#  'Franklin Gothic Medium Cond',
#  'Tahoma',
#  'Californian FB',
#  'Castellar',
#  'Comic Sans MS',
#  'Book Antiqua',
#  'Harlow Solid Italic',
#  'Bodoni MT',
#  'Engravers MT']

# %%
plt.plot(x,y)
plt.title('꺽은선 그래프');

# %%
plt.plot([-1,0,1],[-5,-1,2]);

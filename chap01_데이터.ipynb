# %% [markdown]
# # 데이터에 관하여

# %%
# Pandas를 pd라는 이름으로 임포트한다.
import pandas as pd

# %% [markdown]
# ### 1. 파일 직접 업로드
#     - 구글로 파일 직접 불러오기
#   ```
#       from google.colab import files
#       myyfile = files.upload()
#   ```
#
#     - io와 pandas 모듈 import
#   ```
#      import io
#      import pandas as pd
#    ```
#    - pd.read_csv로 csv파일 불러오기
#    ```
#      data = pd.read_csv(io.BytesIO(myfile['train 2.csv']))
#      data.head()
#    ```

# %%
# 2. 구글 드라이브에서 파일 가져오기
from google.colab import drive
drive.mount('/content/drive')

# %%
# 학생번호를 인덱스로 csv 파일을 읽어들여, 변수 df에 저장
df = pd.read_csv('/content/drive/MyDrive/K-Dgital-numpy/누구나 파이썬 통계분석/python_stat_sample-master/data/ch1_sport_test.csv', index_col='학생번호')
df
# Out:
#       학년    악력  윗몸일으키기  점수  순위
# 학생번호
# 1      1  40.2      34  15   4
# 2      1  34.2      14   7  10
# 3      1  28.8      27  11   7
# 4      2  39.0      27  14   5
# 5      2  50.9      32  17   2
# 6      2  36.5      20   9   9
# 7      3  36.6      31  13   6
# 8      3  49.2      37  18   1
# 9      3  26.0      28  10   8
# 10     3  47.4      32  16   3

# %%
dtype(df['악력'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1c63f681e1c4> in <module>()
# ----> 1 dtype(df['악력'])
#
# NameError: name 'dtype' is not defined

# %%
df.shape
# Out:
# (10, 5)

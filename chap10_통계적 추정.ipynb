# %% [markdown]
# # 통계적 추정

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %precision 3
# %matplotlib inline

# %%
# 구글 드라이브에서 파일 가져오기
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 파일 불러오기
df = pd.read_csv('/content/drive/MyDrive/파이썬/누구나 파이썬 통계분석/python_stat_sample-master(정리)/data/ch4_scores400.csv')
# df의 처음 5행을 표시
df.head()
# Out:
#    score
# 0     76
# 1     55
# 2     80
# 3     80
# 4     74

# %%
# 내 컴퓨터에서 파일 가져오기 
df = pd.read_csv('/content/drive/MyDrive/파이썬/누구나 파이썬 통계분석/python_stat_sample-master(정리)/data/ch4_scores400.csv')
scores = np.array(df['score'])

# %%
p_mean = np.mean(scores)
p_var = np.var(scores)

p_mean, p_var
# Out:
# (69.530, 206.669)

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)

xs = np.arange(101)
rv = stats.norm(p_mean, np.sqrt(p_var))
ax.plot(xs, rv.pdf(xs), color='gray')
ax.hist(scores, bins=100, range=(0,100), density=True)
plt.show()

# %%
np.random.seed(0)
n = 20
sample = np.random.choice(scores, n)
sample
# Out:
# array([49, 60, 72, 86, 52, 61, 77, 91, 80, 56, 69, 67, 90, 56, 75, 79, 60,
#        79, 68, 81])

# %%
np.random.seed(1111)
n_samples = 10000
samples = np.random.choice(scores, (n_samples, n))

# %% [markdown]
# ## 점추정

# %% [markdown]
# ### 모평균의 점추정

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for i in range(5):
    s_mean = np.mean(samples[i])
    print(f'{i+1}번째 표본평균: {s_mean:.3f}')
# Out:
# 1번째 표본평균: 67.000
# 2번째 표본평균: 72.850
# 3번째 표본평균: 69.200
# 4번째 표본평균: 64.450
# 5번째 표본평균: 72.650

# %%
sample_means = np.mean(samples, axis=1)
np.mean(sample_means)
# Out:
# 69.538

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
np.mean(np.random.choice(scores, int(1e6)))
# Out:
# 69.543

# %%
s_mean = np.mean(sample)
s_mean
# Out:
# 70.400

# %% [markdown]
# ### 모분산의 점추정

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for i in range(5):
    s_var = np.var(samples[i])
    print(f'{i+1}번째 표본분산: {s_var:.3f}')
# Out:
# 1번째 표본분산: 116.800
# 2번째 표본분산: 162.928
# 3번째 표본분산: 187.060
# 4번째 표본분산: 149.148
# 5번째 표본분산: 111.528

# %%
sample_vars = np.var(samples, axis=1)
np.mean(sample_vars)
# Out:
# 196.344

# %%
sample_u_vars = np.var(samples, axis=1, ddof=1)
np.mean(sample_u_vars)
# Out:
# 206.678

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
np.var(np.random.choice(scores, int(1e6)), ddof=1)
# Out:
# 206.841

# %%
u_var = np.var(sample, ddof=1)
u_var
# Out:
# 158.253

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 구간추정

# %% [markdown]
# ### 정규분포의 모평균(분산을 알고 있는)의 구간추정

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
rv = stats.norm()
lcl = s_mean - rv.isf(0.025) * np.sqrt(p_var/n)
ucl = s_mean - rv.isf(0.975) * np.sqrt(p_var/n)

lcl, ucl
# Out:
# (64.100, 76.700)

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)

rv = stats.norm()
n_samples = 20
ax.vlines(p_mean, 0, 21)

for i in range(n_samples):
  sample_ = samples[i]
  s_mean_ = np.mean(sample_)
  lcl = s_mean_ - rv.isf(0.025) * np.sqrt(p_var/n)
  ucl = s_mean_ - rv.isf(0.975) * np.sqrt(p_var/n)

  if lcl <= p_mean <= ucl:
    ax.scatter(s_mean_, n_samples-i, color='gray')
    ax.hlines(n_samples-i, lcl, ucl, color='gray')
  else:
    ax.scatter(s_mean_, n_samples-i, color='b')
    ax.hlines(n_samples-i, lcl, ucl, color='b')

ax.set_xticks([p_mean])
ax.set_xticklabels(['population mean'])

plt.show()

# %%
rv = stats.norm()
cnt = 0

for sample_ in samples:
  s_mean_ = np.mean(sample_)
  lcl = s_mean_ - rv.isf(0.025) * np.sqrt(p_var/n)
  ucl = s_mean_ - rv.isf(0.975) * np.sqrt(p_var/n)

  if lcl <= p_mean <= ucl:
    cnt += 1

cnt / len(samples)
# Out:
# 0.951

# %% [markdown]
# ### 정규분포의 모분산(평균을 알지 못하는) 구간추정

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
sample_y = sample_u_vars * (n-1) / p_var
sample_y
# Out:
# array([11.303, 15.767, 18.102, ..., 19.435,  9.265, 18.625])

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)

xs = np.linspace(0, 40, 100)
rv = stats.chi2(df=n-1)
ax.plot(xs, rv.pdf(xs), color='gray')
hist, _, _ = ax.hist(sample_y, bins=100,
                     range=(0, 40), density=True)

plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
rv = stats.chi2(df = n-1)
lcl = (n-1) * u_var / rv.isf(0.025)
hcl = (n-1) * u_var / rv.isf(0.975)
lcl, hcl
# Out:
# (91.525, 337.596)

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)

rv = stats.chi2(df=n-1)
n_samples = 20
ax.vlines(p_var, 0, 21)
for i in range(n_samples):
    sample_ = samples[i]
    u_var_ = np.var(sample_, ddof=1)
    lcl = (n-1) * u_var_ / rv.isf(0.025)
    ucl = (n-1) * u_var_ / rv.isf(0.975)
    if lcl <= p_var <= ucl:
        ax.scatter(u_var_, n_samples-i, color='gray')
        ax.hlines(n_samples-i, lcl, ucl, 'gray')
    else:
        ax.scatter(u_var_, n_samples-i, color='b')
        ax.hlines(n_samples-i, lcl, ucl, 'b')
ax.set_xticks([p_var])
ax.set_xticklabels(['population variance'])

plt.show()

# %%
rv = stats.chi2(df=n-1)
cnt = 0
for sample_ in samples:
    u_var_ = np.var(sample_, ddof=1)
    lcl = (n-1) * u_var_ / rv.isf(0.025)
    ucl = (n-1) * u_var_ / rv.isf(0.975)
    if lcl <= p_var <= ucl:
        cnt += 1
        
cnt / len(samples)
# Out:
# 0.964

# %% [markdown]
# ### 정규분포의 모평균(모분산을 알지 못하는) 구간추정

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
rv = stats.t(df = n-1)
lcl = s_mean - rv.isf(0.025) * np.sqrt(u_var/n)
ucl = s_mean - rv.isf(0.975) * np.sqrt(u_var/n)

lcl, ucl
# Out:
# (64.512, 76.288)

# %% [markdown]
# ### 베르누이 분포의 모평균의 구간추정

# %%
enquete_df = pd.read_csv('/content/drive/MyDrive/파이썬/누구나 파이썬 통계분석/python_stat_sample-master/data/ch10_enquete.csv')
enquete = np.array(enquete_df['known'])
n = len(enquete)
enquete[:10]
# Out:
# array([1, 0, 1, 1, 1, 1, 1, 0, 0, 1])

# %%
s_mean = enquete.mean()
s_mean
# Out:
# 0.709

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
rv = stats.norm()
lcl = s_mean - rv.isf(0.025) * np.sqrt(s_mean * (1 - s_mean)/n)
ucl = s_mean - rv.isf(0.975) * np.sqrt(s_mean * (1 - s_mean)/n)

lcl, ucl
# Out:
# (0.681, 0.737)

# %% [markdown]
# ### 포아송 분포의 모평균의 구간추정

# %%
n_access_df = pd.read_csv('/content/drive/MyDrive/파이썬/누구나 파이썬 통계분석/python_stat_sample-master/data/ch10_access.csv')
n_access = np.array(n_access_df['access number'])
n = len(n_access)
n_access[:10]
# Out:
# array([10, 11,  9,  9, 18, 13,  4, 10, 10,  8])

# %%
s_mean = n_access.mean()
s_mean
# Out:
# 10.444

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
rv = stats.norm()
lcl = s_mean - rv.isf(0.025) * np.sqrt(s_mean/n)
ucl = s_mean - rv.isf(0.975) * np.sqrt(s_mean/n)

lcl, ucl
# Out:
# (9.698, 11.191)

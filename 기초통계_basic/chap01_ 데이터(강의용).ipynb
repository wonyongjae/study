# %% [markdown]
# # 데이터에 관하여

# %%
# Pandas를 pd라는 이름으로 임포트한다
import pandas as pd
import io

# %%
# 1. 컴퓨터에서 파일 직접 가져오기
# 구글로 부터 파일 직접 가져오기

from google.colab import files

myfile = files.upload()
# 구글 코랩에서 files를 가져와서 myfile 에 업로드시킨다
# Out:
#      <input type="file" id="files-1452d3b5-f667-44d6-9fee-abe70f3ee9d1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1452d3b5-f667-44d6-9fee-abe70f3ee9d1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
# !pwd

#리눅스 언어로 파일을 찾음
# Out:
# /content

# %%
# 2. 구글 드라이브에서 파일 가져오기
from google.colab import drive

drive.mount('/content/drive')

#위와 다르게 파일이 아닌 드라이브를 임포트해서 드라이브에 있는 파일을 마운트하는 작업
# Out:
# Mounted at /content/drive

# %%
# 1. 컴퓨터에서 파일 직접 가져오기


# 2. 구글 드라이브에서 파일 가져오기
# Out:
# Mounted at /content/drive

# %%
# 학생번호를 인덱스로 csv 파일을 읽어들여, 변수 df에 저장
df = pd.read_csv('/content/drive/MyDrive/파이썬/누구나 파이썬 통계분석/python_stat_sample-master/data/ch1_sport_test.csv', index_col='학생번호')
# 판다스의 리드 메서드를 이용해서 csv파이를 df 변수에 저장
df 
# 변수출력
# Out:
#       학년    악력  윗몸일으키기  점수  순위
# 학생번호
# 1      1  40.2      34  15   4
# 2      1  34.2      14   7  10
# 3      1  28.8      27  11   7
# 4      2  39.0      27  14   5
# 5      2  50.9      32  17   2
# 6      2  36.5      20   9   9
# 7      3  36.6      31  13   6
# 8      3  49.2      37  18   1
# 9      3  26.0      28  10   8
# 10     3  47.4      32  16   3

# %%
df.악력
# 칼럼을 가져오는 방법 1
# Out:
# 학생번호
# 1     40.2
# 2     34.2
# 3     28.8
# 4     39.0
# 5     50.9
# 6     36.5
# 7     36.6
# 8     49.2
# 9     26.0
# 10    47.4
# Name: 악력, dtype: float64

# %%
df['악력']
# 칼럼을 가져오는 방법 2
# Out:
# 학생번호
# 1     40.2
# 2     34.2
# 3     28.8
# 4     39.0
# 5     50.9
# 6     36.5
# 7     36.6
# 8     49.2
# 9     26.0
# 10    47.4
# Name: 악력, dtype: float64

# %%
df['악력']
# Out:
# 학생번호
# 1     40.2
# 2     34.2
# 3     28.8
# 4     39.0
# 5     50.9
# 6     36.5
# 7     36.6
# 8     49.2
# 9     26.0
# 10    47.4
# Name: 악력, dtype: float64

# %%
df.shape
# shape은 행과 열의 갯수를 알아온다
# Out:
# (10, 5)

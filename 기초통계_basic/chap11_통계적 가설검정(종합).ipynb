# %% [markdown]
# # 통계적 가설검정

# %%
import numpy as np
import pandas as pd
from scipy import stats

# %precision 3
np.random.seed(1111)

# %%
# 구글 드라이브에서 파일 가져오기
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/파이썬/누구나 파이썬 통계분석/python_stat_sample-master(정리)/data/ch11_potato.csv')
sample = np.array(df['무게'])
sample
# Out:
# array([122.02, 131.73, 130.6 , 131.82, 132.05, 126.12, 124.43, 132.89,
#        122.79, 129.95, 126.14, 134.45, 127.64, 125.68])

# %%
s_mean = np.mean(sample)
s_mean
# Out:
# 128.451

# %% [markdown]
# ## 통계적 가설검정이란

# %% [markdown]
# ### 통계적 가설검정의 흐름

# %%
rv = stats.norm(130, np.sqrt(9/14))
rv.isf(0.95)
# Out:
# 128.681

# %%
z = (s_mean - 130) / np.sqrt(9/14)
z
# Out:
# -1.932

# %%
rv = stats.norm()
rv.isf(0.95)
# Out:
# -1.645

# %%
rv.cdf(z)
# Out:
# 0.027

# %% [markdown]
# ### 단측검정과 양측검정

# %%
z = (s_mean - 130) / np.sqrt(9/14)
z
# Out:
# -1.932

# %%
rv = stats.norm()
rv.interval(0.95)
# Out:
# (-1.960, 1.960)

# %%
rv.cdf(z) * 2
# Out:
# 0.053

# %%
rv.cdf(-1.932) * 2
# Out:
# 0.053

# %%
rv.cdf(z) * 2
# Out:
# 0.053

# %%
rv=stats.norm(130, 3)

# %%
rv.rvs()
# Out:
# 126.100

# %% [raw]
# ### 가설검정에서의 두 가지 오류

# %%
rv = stats.norm(130, 3)

# %%
c = stats.norm().isf(0.95)
n_samples = 10000
cnt = 0
for _ in range(n_samples):
    sample_ = np.round(rv.rvs(14), 2)
    s_mean_ = np.mean(sample_)
    z = (s_mean_ - 130) / np.sqrt(9/14)
    if z < c:
        cnt += 1
cnt / n_samples
# Out:
# 0.051

# %%
rv = stats.norm(128, 3)

# %%
c = stats.norm().isf(0.95)
n_samples = 10000
cnt = 0
for _ in range(n_samples):
    sample_ = np.round(rv.rvs(14), 2)
    s_mean_ = np.mean(sample_)
    z = (s_mean_ - 130) / np.sqrt(9/14)
    if z >= c:
        cnt += 1
        
cnt / n_samples
# Out:
# 0.198

# %% [markdown]
# ## 가설검정

# %% [markdown]
# ### 정규분포의 모평균에 대한 검정(모분산을 알고 있음)

# %%
def pmean_test(sample, mean0, p_var, alpha=0.05):
    s_mean = np.mean(sample)
    n = len(sample)
    rv = stats.norm()
    interval = rv.interval(1-alpha)

    z = (s_mean - mean0) / np.sqrt(p_var/n)
    if interval[0] <= z <= interval[1]:
        print('귀무가설을 채택')
    else:
        print('귀무가설을 기각')

    if z < 0:
        p = rv.cdf(z) * 2
    else:
        p = (1 - rv.cdf(z)) * 2
    print(f'p값은 {p:.3f}')

# %%
pmean_test(sample, 130, 9)
# Out:
# 귀무가설을 채택
# p값은 0.053

# %% [markdown]
# ### 정규분포의 모분산에 대한 검정

# %%
def pvar_test(sample, var0, alpha=0.05):
    u_var = np.var(sample, ddof=1)
    n = len(sample)
    rv = stats.chi2(df=n-1)
    interval = rv.interval(1-alpha)
    
    y = (n-1) * u_var / var0
    if interval[0] <= y <= interval[1]:
        print('귀무가설을 채택')
    else:
        print('귀무가설을 기각')

    if y < rv.isf(0.5):
        p = rv.cdf(y) * 2
    else:
        p = (1 - rv.cdf(y)) * 2
    print(f'p값은 {p:.3f}')

# %%
pvar_test(sample, 9)
# Out:
# 귀무가설을 채택
# p값은 0.085

# %% [markdown]
# ### 정규분포의 모평균에 대한 검정(모분산을 알지 못함)

# %%
def pmean_test(sample, mean0, alpha=0.05):
    s_mean = np.mean(sample)
    u_var = np.var(sample, ddof=1)
    n = len(sample)
    rv = stats.t(df=n-1)
    interval = rv.interval(1-alpha)

    t = (s_mean - mean0) / np.sqrt(u_var/n)
    if interval[0] <= t <= interval[1]:
        print('귀무가설을 채택')
    else:
        print('귀무가설을 기각')

    if t < 0:
        p = rv.cdf(t) * 2
    else:
        p = (1 - rv.cdf(t)) * 2
    print(f'p값은 {p:.3f}')

# %%
pmean_test(sample, 130)
# Out:
# 귀무가설을 채택
# p값은 0.169

# %%
t, p = stats.ttest_1samp(sample, 130)
t, p
# Out:
# (-1.455, 0.169)

# %%
rv.cdf(0.169)
# Out:
# 0.000

# %%
rv.cdf(-1.455)
# Out:
# 0.000

# %% [markdown]
# ## 2표본 문제에 관한 가설검정

# %% [markdown]
# ### 대응비교 t검정

# %%
training_rel = pd.read_csv('/content/drive/MyDrive/파이썬/누구나 파이썬 통계분석/python_stat_sample-master(정리)/data/ch11_training_rel.csv')
print(training_rel.shape)
training_rel.head()
# Out:
# (20, 2)
#     전   후
# 0  59  41
# 1  52  63
# 2  55  68
# 3  61  59
# 4  59  84

# %%
training_rel['차'] = training_rel['후'] - training_rel['전']
training_rel.head()
# Out:
#     전   후   차
# 0  59  41 -18
# 1  52  63  11
# 2  55  68  13
# 3  61  59  -2
# 4  59  84  25

# %%
t, p = stats.ttest_1samp(training_rel['차'], 0)
p
# Out:
# 0.040

# %%
t, p = stats.ttest_rel(training_rel['후'], training_rel['전'])
p
# Out:
# 0.040

# %% [markdown]
# ### 독립비교 t검정

# %%
training_ind = pd.read_csv('/content/drive/MyDrive/파이썬/누구나 파이썬 통계분석/python_stat_sample-master(정리)/data/ch11_training_ind.csv')
print(training_ind.shape)
training_ind.head()
# Out:
# (20, 2)
#     A   B
# 0  47  49
# 1  50  52
# 2  37  54
# 3  60  48
# 4  39  51

# %%
t, p = stats.ttest_ind(training_ind['A'], training_ind['B'],
                       equal_var=False)
p
# Out:
# 0.087

# %% [markdown]
# ### 윌콕슨의 부호순위검정

# %%
training_rel = pd.read_csv('/content/drive/MyDrive/파이썬/누구나 파이썬 통계분석/python_stat_sample-master(정리)/data/ch11_training_rel.csv')
toy_df = training_rel[:6].copy()
toy_df
# Out:
#     전   후
# 0  59  41
# 1  52  63
# 2  55  68
# 3  61  59
# 4  59  84
# 5  45  37

# %%
diff = toy_df['후'] - toy_df['전']
toy_df['차'] = diff
toy_df
# Out:
#     전   후   차
# 0  59  41 -18
# 1  52  63  11
# 2  55  68  13
# 3  61  59  -2
# 4  59  84  25
# 5  45  37  -8

# %%
rank = stats.rankdata(abs(diff)).astype(int)
toy_df['순위'] = rank
toy_df
# Out:
#     전   후   차  순위
# 0  59  41 -18   5
# 1  52  63  11   3
# 2  55  68  13   4
# 3  61  59  -2   1
# 4  59  84  25   6
# 5  45  37  -8   2

# %%
r_minus = np.sum((diff < 0) * rank)
r_plus = np.sum((diff > 0) * rank)

r_minus, r_plus
# Out:
# (8, 13)

# %%
T, p = stats.wilcoxon(training_rel['전'], training_rel['후'])
p
# Out:
# 0.038

# %%
T, p = stats.wilcoxon(training_rel['후'] - training_rel['전'])
p
# Out:
# 0.038

# %%
cnt = 0

# %%
cnt = 0
alpha = 0.05
for diff in diffs:

cnt / n
# Out:
#   File "<ipython-input-39-6641a77ba870>", line 5
#     cnt / n
#       ^
# IndentationError: expected an indented block

# %% [markdown]
# ### 만・위트니의 U검정

# %%
training_ind = pd.read_csv('/content/drive/MyDrive/파이썬/누구나 파이썬 통계분석/python_stat_sample-master(정리)/data/ch11_training_ind.csv')
toy_df = training_ind[:5].copy()
toy_df
# Out:
#     A   B
# 0  47  49
# 1  50  52
# 2  37  54
# 3  60  48
# 4  39  51

# %%
u, p = stats.mannwhitneyu(training_ind['A'], training_ind['B'], alternative='tow-sided')
p
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-ba0c196e6e39> in <module>()
# ----> 1 u, p = stats.mannwhitneyu(training_ind['A'], training_ind['B'], alternative='tow-sided')
#       2 p
#
# /usr/local/lib/python3.7/dist-packages/scipy/stats/stats.py in mannwhitneyu(x, y, use_continuity, alternative)
#    6410         bigu = u2
#    6411     else:
# -> 6412         raise ValueError("alternative should be None, 'less', 'greater' "
#    6413                          "or 'two-sided'")
#    6414
#
# ValueError: alternative should be None, 'less', 'greater' or 'two-sided'

# %%
rank = stats.rankdata(np.concatenate([toy_df['A'],

# %% [markdown]
# ### 카이제곱검정

# %%
ad_df = pd.read_csv('../data/ch11_ad.csv')
n = len(ad_df)
print(n)
ad_df.head()

# %%
ad_cross = pd.crosstab(ad_df['광고'], ad_df['구입'])
ad_cross

# %%
ad_cross['했다'] / (ad_cross['했다'] + ad_cross['하지 않았다'])

# %%
n_not, n_yes = ad_cross.sum()
n_not, n_yes

# %%
n_adA, n_adB = ad_cross.sum(axis=1)
n_adA, n_adB

# %%
ad_ef = pd.DataFrame({'했다': [n_adA * n_yes / n,
                              n_adB * n_yes / n],
                      '하지 않았다': [n_adA * n_not / n,
                                   n_adB * n_not / n]},
                      index=['A', 'B'])
ad_ef

# %%
y = ((ad_cross - ad_ef) ** 2 / ad_ef).sum().sum()
y

# %%
rv = stats.chi2(1)
1 - rv.cdf(y)

# %%
chi2, p, dof, ef = stats.chi2_contingency(ad_cross,
                                          correction=False)
chi2, p, dof

# %%
ef
